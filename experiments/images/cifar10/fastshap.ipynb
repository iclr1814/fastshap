# %%
import sys
sys.path.insert(0, '../../../fastshap_tf/')
from fastshap import ImageFastSHAP, ShapleySampler, ResizeMask
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd

# %%
import pickle
import numpy as np
import shap
from tqdm.notebook import tqdm
import time

# %%
import tensorflow as tf
from tensorflow.keras.layers import (Input, Layer, Dense, Lambda, Reshape, Multiply)
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers.experimental.preprocessing import Resizing

from tensorflow.keras.datasets import cifar10

from datetime import datetime
import os

# %%
#Select GPU
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# %%
# IMPORTANT: SET RANDOM SEEDS FOR REPRODUCIBILITY
os.environ['PYTHONHASHSEED'] = str(420)
import random
random.seed(420)
np.random.seed(420)
tf.random.set_seed(420)

# %% [markdown]
# ## Load Data

# %%
BATCH_SIZE = 32
EPOCHS = 100
LR = 1e-3
INPUT_SHAPE = (224, 224, 3)

# %%
from sklearn.model_selection import train_test_split

num_classes = 10

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, train_size=0.5, random_state=420)

x_train = x_train.astype('float32')
x_val = x_val.astype('float32')
x_test = x_test.astype('float32')
#Resize to 224x224

print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'val samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_val = tf.keras.utils.to_categorical(y_val, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# Make TF Dataset
ds_train = tf.data.Dataset.from_tensor_slices((x_train, y_train))
ds_val = tf.data.Dataset.from_tensor_slices((x_val, y_val))
ds_test = tf.data.Dataset.from_tensor_slices((x_test, y_test))
# Out:
# 50000 train samples
# 5000 val samples
# 5000 test samples

# %% [markdown]
# ### Batch Data

# %%
def batch_data(dataset, fn, batch_size=32):
    dataset = dataset.map(fn)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    
    return dataset

# %% [markdown]
# ### Reformat Data

# %%
def reformat(x, y):
    
    x = tf.cast(x, tf.float32)
    x = Resizing(INPUT_SHAPE[0], INPUT_SHAPE[1], interpolation='nearest')(x)
    x = tf.keras.applications.resnet50.preprocess_input(x)
    
    return (x, y)

ds_train = batch_data(ds_train, reformat, BATCH_SIZE)
ds_val = batch_data(ds_val, reformat, BATCH_SIZE)
ds_test = batch_data(ds_test, reformat, BATCH_SIZE)

# %% [markdown]
# ## Load Surrogate Imputer

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

P = 14*14
value_model = ResNet50(
    include_top=False, weights='imagenet', 
    input_shape=INPUT_SHAPE, pooling='avg'
) 
D = 10

model_input = Input(shape=INPUT_SHAPE, dtype='float64', name='input')
S = ShapleySampler(P, paired_sampling=False, num_samples=1)(model_input)
S = Lambda(lambda x: tf.cast(x, tf.float32))(S)
S = Reshape((P,))(S)
S = ResizeMask(in_shape=INPUT_SHAPE, mask_size=P)(S)
xs = Multiply()([model_input, S])

net = value_model(xs)
out = Dense(D, activation='softmax')(net)

surrogate = Model(model_input, out)

# Get Checkpointed Model
weights_path = 'surrogate/20210515_01_11_10/value_weights.h5'
surrogate.load_weights(weights_path)

# Remove Masking Layer
surrogate = Sequential(   
    [l for l in surrogate.layers[-2:]]
)
surrogate.trainable = False
# Out:
# WARNING:tensorflow:Layer shapley_sampler is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer multiply is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.

# %% [markdown]
# # Train FastSHAP

# %% [markdown]
# ### Save Dir

# %%
date = datetime.now().strftime("%Y%m%d_%H_%M_%S")
save_dir = 'fastshap'
model_dir = os.path.join(os.getcwd(), save_dir, date)
if not os.path.isdir(model_dir):
    os.makedirs(model_dir)

# %% [markdown]
# ### Initialize

# %%
from importlib import reload
import fastshap
import utils
reload(fastshap)
reload(utils)
from fastshap import ImageFastSHAP

# %%
fastshap = ImageFastSHAP(imputer = surrogate,
                         normalization=None,
                         model_dir = model_dir, 
                         link='logit')

# %% [markdown]
# ### Train

# %%
t = time.time()
fastshap.train(train_data = ds_train, 
              val_data = ds_val, 
              max_epochs = EPOCHS, 
              batch_size = BATCH_SIZE, 
              num_samples = 1,
              lr = LR,
              paired_sampling = True, 
              eff_lambda = 0.0,
              verbose = 1,
              lookback = 20)
training_time = time.time() - t

with open(os.path.join(model_dir, 'training_time.pkl'), 'wb') as f:
    pickle.dump(training_time, f)
# Out:
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda_1), but
# are not present in its tracked objects:
#   <tf.Variable 'conv1_conv/kernel:0' shape=(7, 7, 3, 64) dtype=float32>
#   <tf.Variable 'conv1_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv1_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv1_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_0_conv/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
#   <tf.Variable 'conv2_block1_0_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block1_0_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block1_0_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block1_1_conv/kernel:0' shape=(1, 1, 64, 64) dtype=float32>
#   <tf.Variable 'conv2_block1_1_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_1_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_1_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_2_conv/kernel:0' shape=(3, 3, 64, 64) dtype=float32>
#   <tf.Variable 'conv2_block1_2_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_2_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_2_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_3_conv/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
#   <tf.Variable 'conv2_block1_3_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block1_3_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block1_3_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block2_1_conv/kernel:0' shape=(1, 1, 256, 64) dtype=float32>
#   <tf.Variable 'conv2_block2_1_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_1_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_1_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_2_conv/kernel:0' shape=(3, 3, 64, 64) dtype=float32>
#   <tf.Variable 'conv2_block2_2_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_2_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_2_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_3_conv/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
#   <tf.Variable 'conv2_block2_3_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block2_3_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block2_3_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block3_1_conv/kernel:0' shape=(1, 1, 256, 64) dtype=float32>
#   <tf.Variable 'conv2_block3_1_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_1_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_1_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_2_conv/kernel:0' shape=(3, 3, 64, 64) dtype=float32>
#   <tf.Variable 'conv2_block3_2_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_2_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_2_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_3_conv/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
#   <tf.Variable 'conv2_block3_3_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block3_3_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block3_3_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv3_block1_0_conv/kernel:0' shape=(1, 1, 256, 512) dtype=float32>
#   <tf.Variable 'conv3_block1_0_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block1_0_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block1_0_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block1_1_conv/kernel:0' shape=(1, 1, 256, 128) dtype=float32>
#   <tf.Variable 'conv3_block1_1_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_1_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_1_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_2_conv/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
#   <tf.Variable 'conv3_block1_2_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_2_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_2_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_3_conv/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
#   <tf.Variable 'conv3_block1_3_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block1_3_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block1_3_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block2_1_conv/kernel:0' shape=(1, 1, 512, 128) dtype=float32>
#   <tf.Variable 'conv3_block2_1_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_1_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_1_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_2_conv/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
#   <tf.Variable 'conv3_block2_2_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_2_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_2_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_3_conv/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
#   <tf.Variable 'conv3_block2_3_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block2_3_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block2_3_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block3_1_conv/kernel:0' shape=(1, 1, 512, 128) dtype=float32>
#   <tf.Variable 'conv3_block3_1_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_1_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_1_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_2_conv/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
#   <tf.Variable 'conv3_block3_2_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_2_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_2_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_3_conv/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
#   <tf.Variable 'conv3_block3_3_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block3_3_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block3_3_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block4_1_conv/kernel:0' shape=(1, 1, 512, 128) dtype=float32>
#   <tf.Variable 'conv3_block4_1_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_1_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_1_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_2_conv/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
#   <tf.Variable 'conv3_block4_2_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_2_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_2_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_3_conv/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
#   <tf.Variable 'conv3_block4_3_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block4_3_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block4_3_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv4_block1_0_conv/kernel:0' shape=(1, 1, 512, 1024) dtype=float32>
#   <tf.Variable 'conv4_block1_0_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block1_0_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block1_0_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block1_1_conv/kernel:0' shape=(1, 1, 512, 256) dtype=float32>
#   <tf.Variable 'conv4_block1_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block1_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block1_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block1_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block1_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block2_1_conv/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
#   <tf.Variable 'conv4_block2_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block2_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block2_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block2_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block2_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block3_1_conv/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
#   <tf.Variable 'conv4_block3_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block3_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block3_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block3_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block3_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block4_1_conv/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
#   <tf.Variable 'conv4_block4_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block4_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block4_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block4_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block4_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block5_1_conv/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
#   <tf.Variable 'conv4_block5_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block5_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block5_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block5_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block5_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block6_1_conv/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
#   <tf.Variable 'conv4_block6_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block6_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block6_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block6_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block6_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv5_block1_0_conv/kernel:0' shape=(1, 1, 1024, 2048) dtype=float32>
#   <tf.Variable 'conv5_block1_0_conv/bias:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block1_0_bn/gamma:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block1_0_bn/beta:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block1_1_conv/kernel:0' shape=(1, 1, 1024, 512) dtype=float32>
#   <tf.Variable 'conv5_block1_1_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_1_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_1_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_2_conv/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
#   <tf.Variable 'conv5_block1_2_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_2_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_2_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_3_conv/kernel:0' shape=(1, 1, 512, 2048) dtype=float32>
#   <tf.Variable 'conv5_block1_3_conv/bias:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block1_3_bn/gamma:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block1_3_bn/beta:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block2_1_conv/kernel:0' shape=(1, 1, 2048, 512) dtype=float32>
#   <tf.Variable 'conv5_block2_1_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_1_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_1_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_2_conv/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
#   <tf.Variable 'conv5_block2_2_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_2_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_2_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_3_conv/kernel:0' shape=(1, 1, 512, 2048) dtype=float32>
#   <tf.Variable 'conv5_block2_3_conv/bias:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block2_3_bn/gamma:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block2_3_bn/beta:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block3_1_conv/kernel:0' shape=(1, 1, 2048, 512) dtype=float32>
#   <tf.Variable 'conv5_block3_1_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_1_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_1_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_2_conv/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
#   <tf.Variable 'conv5_block3_2_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_2_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_2_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_3_conv/kernel:0' shape=(1, 1, 512, 2048) dtype=float32>
#   <tf.Variable 'conv5_block3_3_conv/bias:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block3_3_bn/gamma:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block3_3_bn/beta:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'dense/kernel:0' shape=(2048, 10) dtype=float32>
#   <tf.Variable 'dense/bias:0' shape=(10,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# Epoch 1/100
# 1563/1563 [==============================] - ETA: 0s - loss: 60.2409 - shap_loss: 60.2409 - eff_loss: 0.0000e+00
# Epoch 00001: val_shap_loss improved from inf to 25.81140, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 361s 231ms/step - loss: 60.2409 - shap_loss: 60.2409 - eff_loss: 0.0000e+00 - val_loss: 25.8114 - val_shap_loss: 25.8114 - val_eff_loss: 0.0000e+00
# Epoch 2/100
# 1563/1563 [==============================] - ETA: 0s - loss: 25.8413 - shap_loss: 25.8413 - eff_loss: 0.0000e+00
# Epoch 00002: val_shap_loss improved from 25.81140 to 25.06451, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 267s 171ms/step - loss: 25.8413 - shap_loss: 25.8413 - eff_loss: 0.0000e+00 - val_loss: 25.0645 - val_shap_loss: 25.0645 - val_eff_loss: 0.0000e+00
# Epoch 3/100
# 1563/1563 [==============================] - ETA: 0s - loss: 22.4470 - shap_loss: 22.4470 - eff_loss: 0.0000e+00
# Epoch 00003: val_shap_loss improved from 25.06451 to 21.90743, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 267s 171ms/step - loss: 22.4470 - shap_loss: 22.4470 - eff_loss: 0.0000e+00 - val_loss: 21.9074 - val_shap_loss: 21.9074 - val_eff_loss: 0.0000e+00
# Epoch 4/100
# 1563/1563 [==============================] - ETA: 0s - loss: 20.9703 - shap_loss: 20.9703 - eff_loss: 0.0000e+00
# Epoch 00004: val_shap_loss improved from 21.90743 to 21.28881, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 267s 171ms/step - loss: 20.9703 - shap_loss: 20.9703 - eff_loss: 0.0000e+00 - val_loss: 21.2888 - val_shap_loss: 21.2888 - val_eff_loss: 0.0000e+00
# Epoch 5/100
# 1563/1563 [==============================] - ETA: 0s - loss: 19.9481 - shap_loss: 19.9481 - eff_loss: 0.0000e+00
# Epoch 00005: val_shap_loss improved from 21.28881 to 19.02007, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 267s 171ms/step - loss: 19.9481 - shap_loss: 19.9481 - eff_loss: 0.0000e+00 - val_loss: 19.0201 - val_shap_loss: 19.0201 - val_eff_loss: 0.0000e+00
# Epoch 6/100
# 1563/1563 [==============================] - ETA: 0s - loss: 19.1619 - shap_loss: 19.1619 - eff_loss: 0.0000e+00
# Epoch 00006: val_shap_loss improved from 19.02007 to 18.65989, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 267s 171ms/step - loss: 19.1619 - shap_loss: 19.1619 - eff_loss: 0.0000e+00 - val_loss: 18.6599 - val_shap_loss: 18.6599 - val_eff_loss: 0.0000e+00
# Epoch 7/100
# 1563/1563 [==============================] - ETA: 0s - loss: 18.6016 - shap_loss: 18.6016 - eff_loss: 0.0000e+00
# Epoch 00007: val_shap_loss did not improve from 18.65989
# 1563/1563 [==============================] - 267s 171ms/step - loss: 18.6016 - shap_loss: 18.6016 - eff_loss: 0.0000e+00 - val_loss: 19.6199 - val_shap_loss: 19.6199 - val_eff_loss: 0.0000e+00
# Epoch 8/100
# 1563/1563 [==============================] - ETA: 0s - loss: 18.1744 - shap_loss: 18.1744 - eff_loss: 0.0000e+00
# Epoch 00008: val_shap_loss improved from 18.65989 to 18.46733, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 267s 171ms/step - loss: 18.1744 - shap_loss: 18.1744 - eff_loss: 0.0000e+00 - val_loss: 18.4673 - val_shap_loss: 18.4673 - val_eff_loss: 0.0000e+00
# Epoch 9/100
# 1563/1563 [==============================] - ETA: 0s - loss: 17.8928 - shap_loss: 17.8928 - eff_loss: 0.0000e+00
# Epoch 00009: val_shap_loss did not improve from 18.46733
# 1563/1563 [==============================] - 267s 171ms/step - loss: 17.8928 - shap_loss: 17.8928 - eff_loss: 0.0000e+00 - val_loss: 18.6876 - val_shap_loss: 18.6876 - val_eff_loss: 0.0000e+00
# Epoch 10/100
# 1563/1563 [==============================] - ETA: 0s - loss: 17.5700 - shap_loss: 17.5700 - eff_loss: 0.0000e+00
# Epoch 00010: val_shap_loss improved from 18.46733 to 18.28879, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 267s 171ms/step - loss: 17.5700 - shap_loss: 17.5700 - eff_loss: 0.0000e+00 - val_loss: 18.2888 - val_shap_loss: 18.2888 - val_eff_loss: 0.0000e+00
# Epoch 11/100
# 1563/1563 [==============================] - ETA: 0s - loss: 17.1386 - shap_loss: 17.1386 - eff_loss: 0.0000e+00
# Epoch 00011: val_shap_loss did not improve from 18.28879
# 1563/1563 [==============================] - 267s 171ms/step - loss: 17.1386 - shap_loss: 17.1386 - eff_loss: 0.0000e+00 - val_loss: 18.4954 - val_shap_loss: 18.4954 - val_eff_loss: 0.0000e+00
# Epoch 12/100
# 1563/1563 [==============================] - ETA: 0s - loss: 16.9043 - shap_loss: 16.9043 - eff_loss: 0.0000e+00
# Epoch 00012: val_shap_loss did not improve from 18.28879
# 1563/1563 [==============================] - 267s 171ms/step - loss: 16.9043 - shap_loss: 16.9043 - eff_loss: 0.0000e+00 - val_loss: 18.3950 - val_shap_loss: 18.3950 - val_eff_loss: 0.0000e+00
# Epoch 13/100
# 1563/1563 [==============================] - ETA: 0s - loss: 16.6452 - shap_loss: 16.6452 - eff_loss: 0.0000e+00
# Epoch 00013: val_shap_loss improved from 18.28879 to 18.11175, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 267s 171ms/step - loss: 16.6452 - shap_loss: 16.6452 - eff_loss: 0.0000e+00 - val_loss: 18.1117 - val_shap_loss: 18.1117 - val_eff_loss: 0.0000e+00
# Epoch 14/100
# 1563/1563 [==============================] - ETA: 0s - loss: 16.5604 - shap_loss: 16.5604 - eff_loss: 0.0000e+00
# Epoch 00014: val_shap_loss improved from 18.11175 to 17.75276, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 267s 171ms/step - loss: 16.5604 - shap_loss: 16.5604 - eff_loss: 0.0000e+00 - val_loss: 17.7528 - val_shap_loss: 17.7528 - val_eff_loss: 0.0000e+00
# Epoch 15/100
# 1563/1563 [==============================] - ETA: 0s - loss: 16.4165 - shap_loss: 16.4165 - eff_loss: 0.0000e+00
# Epoch 00015: val_shap_loss did not improve from 17.75276
# 1563/1563 [==============================] - 267s 171ms/step - loss: 16.4165 - shap_loss: 16.4165 - eff_loss: 0.0000e+00 - val_loss: 18.2445 - val_shap_loss: 18.2445 - val_eff_loss: 0.0000e+00
# Epoch 16/100
# 1563/1563 [==============================] - ETA: 0s - loss: 16.3165 - shap_loss: 16.3165 - eff_loss: 0.0000e+00
# Epoch 00016: val_shap_loss improved from 17.75276 to 17.27994, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 267s 171ms/step - loss: 16.3165 - shap_loss: 16.3165 - eff_loss: 0.0000e+00 - val_loss: 17.2799 - val_shap_loss: 17.2799 - val_eff_loss: 0.0000e+00
# Epoch 17/100
# 1563/1563 [==============================] - ETA: 0s - loss: 16.1711 - shap_loss: 16.1711 - eff_loss: 0.0000e+00
# Epoch 00017: val_shap_loss did not improve from 17.27994
# 1563/1563 [==============================] - 260s 167ms/step - loss: 16.1711 - shap_loss: 16.1711 - eff_loss: 0.0000e+00 - val_loss: 18.1716 - val_shap_loss: 18.1716 - val_eff_loss: 0.0000e+00
# Epoch 18/100
# 1563/1563 [==============================] - ETA: 0s - loss: 16.1871 - shap_loss: 16.1871 - eff_loss: 0.0000e+00
# Epoch 00018: val_shap_loss improved from 17.27994 to 16.91743, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 261s 167ms/step - loss: 16.1871 - shap_loss: 16.1871 - eff_loss: 0.0000e+00 - val_loss: 16.9174 - val_shap_loss: 16.9174 - val_eff_loss: 0.0000e+00
# Epoch 19/100
# 1563/1563 [==============================] - ETA: 0s - loss: 16.0372 - shap_loss: 16.0372 - eff_loss: 0.0000e+00
# Epoch 00019: val_shap_loss did not improve from 16.91743
# 1563/1563 [==============================] - 260s 167ms/step - loss: 16.0372 - shap_loss: 16.0372 - eff_loss: 0.0000e+00 - val_loss: 18.3632 - val_shap_loss: 18.3632 - val_eff_loss: 0.0000e+00
# Epoch 20/100
# 1563/1563 [==============================] - ETA: 0s - loss: 15.8908 - shap_loss: 15.8908 - eff_loss: 0.0000e+00
# Epoch 00020: val_shap_loss did not improve from 16.91743
# 1563/1563 [==============================] - 260s 167ms/step - loss: 15.8908 - shap_loss: 15.8908 - eff_loss: 0.0000e+00 - val_loss: 18.1049 - val_shap_loss: 18.1049 - val_eff_loss: 0.0000e+00
# Epoch 21/100
# 1563/1563 [==============================] - ETA: 0s - loss: 15.6986 - shap_loss: 15.6986 - eff_loss: 0.0000e+00
# Epoch 00021: val_shap_loss did not improve from 16.91743
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 1563/1563 [==============================] - 260s 167ms/step - loss: 15.6986 - shap_loss: 15.6986 - eff_loss: 0.0000e+00 - val_loss: 17.5383 - val_shap_loss: 17.5383 - val_eff_loss: 0.0000e+00
# Epoch 22/100
# 1563/1563 [==============================] - ETA: 0s - loss: 15.5728 - shap_loss: 15.5728 - eff_loss: 0.0000e+00
# Epoch 00022: val_shap_loss improved from 16.91743 to 16.89459, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 261s 167ms/step - loss: 15.5728 - shap_loss: 15.5728 - eff_loss: 0.0000e+00 - val_loss: 16.8946 - val_shap_loss: 16.8946 - val_eff_loss: 0.0000e+00
# Epoch 23/100
# 1563/1563 [==============================] - ETA: 0s - loss: 15.4143 - shap_loss: 15.4143 - eff_loss: 0.0000e+00
# Epoch 00023: val_shap_loss improved from 16.89459 to 16.70840, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 261s 167ms/step - loss: 15.4143 - shap_loss: 15.4143 - eff_loss: 0.0000e+00 - val_loss: 16.7084 - val_shap_loss: 16.7084 - val_eff_loss: 0.0000e+00
# Epoch 24/100
# 1563/1563 [==============================] - ETA: 0s - loss: 15.3295 - shap_loss: 15.3295 - eff_loss: 0.0000e+00
# Epoch 00024: val_shap_loss did not improve from 16.70840
# 1563/1563 [==============================] - 260s 167ms/step - loss: 15.3295 - shap_loss: 15.3295 - eff_loss: 0.0000e+00 - val_loss: 17.0165 - val_shap_loss: 17.0165 - val_eff_loss: 0.0000e+00
# Epoch 25/100
# 1563/1563 [==============================] - ETA: 0s - loss: 15.2214 - shap_loss: 15.2214 - eff_loss: 0.0000e+00
# Epoch 00025: val_shap_loss improved from 16.70840 to 16.65664, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 261s 167ms/step - loss: 15.2214 - shap_loss: 15.2214 - eff_loss: 0.0000e+00 - val_loss: 16.6566 - val_shap_loss: 16.6566 - val_eff_loss: 0.0000e+00
# Epoch 26/100
# 1563/1563 [==============================] - ETA: 0s - loss: 15.3906 - shap_loss: 15.3906 - eff_loss: 0.0000e+00
# Epoch 00026: val_shap_loss did not improve from 16.65664
# 1563/1563 [==============================] - 260s 167ms/step - loss: 15.3906 - shap_loss: 15.3906 - eff_loss: 0.0000e+00 - val_loss: 16.8066 - val_shap_loss: 16.8066 - val_eff_loss: 0.0000e+00
# Epoch 27/100
# 1563/1563 [==============================] - ETA: 0s - loss: 15.2106 - shap_loss: 15.2106 - eff_loss: 0.0000e+00
# Epoch 00027: val_shap_loss did not improve from 16.65664
# 1563/1563 [==============================] - 260s 167ms/step - loss: 15.2106 - shap_loss: 15.2106 - eff_loss: 0.0000e+00 - val_loss: 16.8640 - val_shap_loss: 16.8640 - val_eff_loss: 0.0000e+00
# Epoch 28/100
# 1563/1563 [==============================] - ETA: 0s - loss: 15.1167 - shap_loss: 15.1167 - eff_loss: 0.0000e+00
# Epoch 00028: val_shap_loss improved from 16.65664 to 16.30982, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 261s 167ms/step - loss: 15.1167 - shap_loss: 15.1167 - eff_loss: 0.0000e+00 - val_loss: 16.3098 - val_shap_loss: 16.3098 - val_eff_loss: 0.0000e+00
# Epoch 29/100
# 1563/1563 [==============================] - ETA: 0s - loss: 15.0907 - shap_loss: 15.0907 - eff_loss: 0.0000e+00
# Epoch 00029: val_shap_loss did not improve from 16.30982
# 1563/1563 [==============================] - 260s 167ms/step - loss: 15.0907 - shap_loss: 15.0907 - eff_loss: 0.0000e+00 - val_loss: 16.4644 - val_shap_loss: 16.4644 - val_eff_loss: 0.0000e+00
# Epoch 30/100
# 1563/1563 [==============================] - ETA: 0s - loss: 15.1356 - shap_loss: 15.1356 - eff_loss: 0.0000e+00
# Epoch 00030: val_shap_loss improved from 16.30982 to 16.16506, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 261s 167ms/step - loss: 15.1356 - shap_loss: 15.1356 - eff_loss: 0.0000e+00 - val_loss: 16.1651 - val_shap_loss: 16.1651 - val_eff_loss: 0.0000e+00
# Epoch 31/100
# 1563/1563 [==============================] - ETA: 0s - loss: 15.0324 - shap_loss: 15.0324 - eff_loss: 0.0000e+00
# Epoch 00031: val_shap_loss did not improve from 16.16506
# 1563/1563 [==============================] - 260s 167ms/step - loss: 15.0324 - shap_loss: 15.0324 - eff_loss: 0.0000e+00 - val_loss: 16.7153 - val_shap_loss: 16.7153 - val_eff_loss: 0.0000e+00
# Epoch 32/100
# 1563/1563 [==============================] - ETA: 0s - loss: 15.0356 - shap_loss: 15.0356 - eff_loss: 0.0000e+00
# Epoch 00032: val_shap_loss did not improve from 16.16506
# 1563/1563 [==============================] - 260s 167ms/step - loss: 15.0356 - shap_loss: 15.0356 - eff_loss: 0.0000e+00 - val_loss: 17.2077 - val_shap_loss: 17.2077 - val_eff_loss: 0.0000e+00
# Epoch 33/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.9935 - shap_loss: 14.9935 - eff_loss: 0.0000e+00
# Epoch 00033: val_shap_loss did not improve from 16.16506
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.9935 - shap_loss: 14.9935 - eff_loss: 0.0000e+00 - val_loss: 16.8019 - val_shap_loss: 16.8019 - val_eff_loss: 0.0000e+00
# Epoch 34/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.8374 - shap_loss: 14.8374 - eff_loss: 0.0000e+00
# Epoch 00034: val_shap_loss did not improve from 16.16506
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.8374 - shap_loss: 14.8374 - eff_loss: 0.0000e+00 - val_loss: 16.5088 - val_shap_loss: 16.5088 - val_eff_loss: 0.0000e+00
# Epoch 35/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.8500 - shap_loss: 14.8500 - eff_loss: 0.0000e+00
# Epoch 00035: val_shap_loss did not improve from 16.16506
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.8500 - shap_loss: 14.8500 - eff_loss: 0.0000e+00 - val_loss: 16.7987 - val_shap_loss: 16.7987 - val_eff_loss: 0.0000e+00
# Epoch 36/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.7197 - shap_loss: 14.7197 - eff_loss: 0.0000e+00
# Epoch 00036: val_shap_loss improved from 16.16506 to 16.04253, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 261s 167ms/step - loss: 14.7197 - shap_loss: 14.7197 - eff_loss: 0.0000e+00 - val_loss: 16.0425 - val_shap_loss: 16.0425 - val_eff_loss: 0.0000e+00
# Epoch 37/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.6754 - shap_loss: 14.6754 - eff_loss: 0.0000e+00
# Epoch 00037: val_shap_loss did not improve from 16.04253
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.6754 - shap_loss: 14.6754 - eff_loss: 0.0000e+00 - val_loss: 16.0897 - val_shap_loss: 16.0897 - val_eff_loss: 0.0000e+00
# Epoch 38/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.7488 - shap_loss: 14.7488 - eff_loss: 0.0000e+00
# Epoch 00038: val_shap_loss did not improve from 16.04253
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.7488 - shap_loss: 14.7488 - eff_loss: 0.0000e+00 - val_loss: 16.6170 - val_shap_loss: 16.6170 - val_eff_loss: 0.0000e+00
# Epoch 39/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.7210 - shap_loss: 14.7210 - eff_loss: 0.0000e+00
# Epoch 00039: val_shap_loss did not improve from 16.04253
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.7210 - shap_loss: 14.7210 - eff_loss: 0.0000e+00 - val_loss: 16.8922 - val_shap_loss: 16.8922 - val_eff_loss: 0.0000e+00
# Epoch 40/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.5969 - shap_loss: 14.5969 - eff_loss: 0.0000e+00
# Epoch 00040: val_shap_loss improved from 16.04253 to 15.72538, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 261s 167ms/step - loss: 14.5969 - shap_loss: 14.5969 - eff_loss: 0.0000e+00 - val_loss: 15.7254 - val_shap_loss: 15.7254 - val_eff_loss: 0.0000e+00
# Epoch 41/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.4674 - shap_loss: 14.4674 - eff_loss: 0.0000e+00
# Epoch 00041: val_shap_loss did not improve from 15.72538
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.4674 - shap_loss: 14.4674 - eff_loss: 0.0000e+00 - val_loss: 16.0522 - val_shap_loss: 16.0522 - val_eff_loss: 0.0000e+00
# Epoch 42/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.5200 - shap_loss: 14.5200 - eff_loss: 0.0000e+00
# Epoch 00042: val_shap_loss did not improve from 15.72538
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.5200 - shap_loss: 14.5200 - eff_loss: 0.0000e+00 - val_loss: 16.1743 - val_shap_loss: 16.1743 - val_eff_loss: 0.0000e+00
# Epoch 43/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.6178 - shap_loss: 14.6178 - eff_loss: 0.0000e+00
# Epoch 00043: val_shap_loss did not improve from 15.72538
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.6178 - shap_loss: 14.6178 - eff_loss: 0.0000e+00 - val_loss: 16.2255 - val_shap_loss: 16.2255 - val_eff_loss: 0.0000e+00
# Epoch 44/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.4406 - shap_loss: 14.4406 - eff_loss: 0.0000e+00
# Epoch 00044: val_shap_loss did not improve from 15.72538
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.4406 - shap_loss: 14.4406 - eff_loss: 0.0000e+00 - val_loss: 16.4171 - val_shap_loss: 16.4171 - val_eff_loss: 0.0000e+00
# Epoch 45/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.3265 - shap_loss: 14.3265 - eff_loss: 0.0000e+00
# Epoch 00045: val_shap_loss did not improve from 15.72538
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.3265 - shap_loss: 14.3265 - eff_loss: 0.0000e+00 - val_loss: 15.9623 - val_shap_loss: 15.9623 - val_eff_loss: 0.0000e+00
# Epoch 46/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.2994 - shap_loss: 14.2994 - eff_loss: 0.0000e+00
# Epoch 00046: val_shap_loss did not improve from 15.72538
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.2994 - shap_loss: 14.2994 - eff_loss: 0.0000e+00 - val_loss: 15.9647 - val_shap_loss: 15.9647 - val_eff_loss: 0.0000e+00
# Epoch 47/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.2781 - shap_loss: 14.2781 - eff_loss: 0.0000e+00
# Epoch 00047: val_shap_loss did not improve from 15.72538
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.2781 - shap_loss: 14.2781 - eff_loss: 0.0000e+00 - val_loss: 15.8332 - val_shap_loss: 15.8332 - val_eff_loss: 0.0000e+00
# Epoch 48/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.3243 - shap_loss: 14.3243 - eff_loss: 0.0000e+00
# Epoch 00048: val_shap_loss did not improve from 15.72538
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.3243 - shap_loss: 14.3243 - eff_loss: 0.0000e+00 - val_loss: 15.8751 - val_shap_loss: 15.8751 - val_eff_loss: 0.0000e+00
# Epoch 49/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.2558 - shap_loss: 14.2558 - eff_loss: 0.0000e+00
# Epoch 00049: val_shap_loss did not improve from 15.72538
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.2558 - shap_loss: 14.2558 - eff_loss: 0.0000e+00 - val_loss: 16.0824 - val_shap_loss: 16.0824 - val_eff_loss: 0.0000e+00
# Epoch 50/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.2177 - shap_loss: 14.2177 - eff_loss: 0.0000e+00
# Epoch 00050: val_shap_loss did not improve from 15.72538
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.2177 - shap_loss: 14.2177 - eff_loss: 0.0000e+00 - val_loss: 16.0737 - val_shap_loss: 16.0737 - val_eff_loss: 0.0000e+00
# Epoch 51/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.2181 - shap_loss: 14.2181 - eff_loss: 0.0000e+00
# Epoch 00051: val_shap_loss did not improve from 15.72538
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.2181 - shap_loss: 14.2181 - eff_loss: 0.0000e+00 - val_loss: 15.9590 - val_shap_loss: 15.9590 - val_eff_loss: 0.0000e+00
# Epoch 52/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.1596 - shap_loss: 14.1596 - eff_loss: 0.0000e+00
# Epoch 00052: val_shap_loss did not improve from 15.72538
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.1596 - shap_loss: 14.1596 - eff_loss: 0.0000e+00 - val_loss: 15.7951 - val_shap_loss: 15.7951 - val_eff_loss: 0.0000e+00
# Epoch 53/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.0718 - shap_loss: 14.0718 - eff_loss: 0.0000e+00
# Epoch 00053: val_shap_loss did not improve from 15.72538
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.0718 - shap_loss: 14.0718 - eff_loss: 0.0000e+00 - val_loss: 15.9926 - val_shap_loss: 15.9926 - val_eff_loss: 0.0000e+00
# Epoch 54/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.1175 - shap_loss: 14.1175 - eff_loss: 0.0000e+00
# Epoch 00054: val_shap_loss did not improve from 15.72538
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.1175 - shap_loss: 14.1175 - eff_loss: 0.0000e+00 - val_loss: 15.9297 - val_shap_loss: 15.9297 - val_eff_loss: 0.0000e+00
# Epoch 55/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.1095 - shap_loss: 14.1095 - eff_loss: 0.0000e+00
# Epoch 00055: val_shap_loss improved from 15.72538 to 15.50072, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/cifar10/fastshap/20210519_16_07_53/explainer_weights.h5
# 1563/1563 [==============================] - 261s 167ms/step - loss: 14.1095 - shap_loss: 14.1095 - eff_loss: 0.0000e+00 - val_loss: 15.5007 - val_shap_loss: 15.5007 - val_eff_loss: 0.0000e+00
# Epoch 56/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.0542 - shap_loss: 14.0542 - eff_loss: 0.0000e+00
# Epoch 00056: val_shap_loss did not improve from 15.50072
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.0542 - shap_loss: 14.0542 - eff_loss: 0.0000e+00 - val_loss: 16.3506 - val_shap_loss: 16.3506 - val_eff_loss: 0.0000e+00
# Epoch 57/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.0234 - shap_loss: 14.0234 - eff_loss: 0.0000e+00
# Epoch 00057: val_shap_loss did not improve from 15.50072
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.0234 - shap_loss: 14.0234 - eff_loss: 0.0000e+00 - val_loss: 16.1095 - val_shap_loss: 16.1095 - val_eff_loss: 0.0000e+00
# Epoch 58/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.0302 - shap_loss: 14.0302 - eff_loss: 0.0000e+00
# Epoch 00058: val_shap_loss did not improve from 15.50072
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.0302 - shap_loss: 14.0302 - eff_loss: 0.0000e+00 - val_loss: 15.8949 - val_shap_loss: 15.8949 - val_eff_loss: 0.0000e+00
# Epoch 59/100
# 1563/1563 [==============================] - ETA: 0s - loss: 13.9776 - shap_loss: 13.9776 - eff_loss: 0.0000e+00
# Epoch 00059: val_shap_loss did not improve from 15.50072
# 1563/1563 [==============================] - 260s 167ms/step - loss: 13.9776 - shap_loss: 13.9776 - eff_loss: 0.0000e+00 - val_loss: 15.6759 - val_shap_loss: 15.6759 - val_eff_loss: 0.0000e+00
# Epoch 60/100
# 1563/1563 [==============================] - ETA: 0s - loss: 13.9697 - shap_loss: 13.9697 - eff_loss: 0.0000e+00
# Epoch 00060: val_shap_loss did not improve from 15.50072
# 1563/1563 [==============================] - 260s 167ms/step - loss: 13.9697 - shap_loss: 13.9697 - eff_loss: 0.0000e+00 - val_loss: 15.7239 - val_shap_loss: 15.7239 - val_eff_loss: 0.0000e+00
# Epoch 61/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.0016 - shap_loss: 14.0016 - eff_loss: 0.0000e+00
# Epoch 00061: val_shap_loss did not improve from 15.50072
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.0016 - shap_loss: 14.0016 - eff_loss: 0.0000e+00 - val_loss: 15.9696 - val_shap_loss: 15.9696 - val_eff_loss: 0.0000e+00
# Epoch 62/100
# 1563/1563 [==============================] - ETA: 0s - loss: 14.0114 - shap_loss: 14.0114 - eff_loss: 0.0000e+00
# Epoch 00062: val_shap_loss did not improve from 15.50072
# 1563/1563 [==============================] - 260s 167ms/step - loss: 14.0114 - shap_loss: 14.0114 - eff_loss: 0.0000e+00 - val_loss: 15.9894 - val_shap_loss: 15.9894 - val_eff_loss: 0.0000e+00
# Epoch 63/100
# 1563/1563 [==============================] - ETA: 0s - loss: 13.9101 - shap_loss: 13.9101 - eff_loss: 0.0000e+00
# Epoch 00063: val_shap_loss did not improve from 15.50072
# 1563/1563 [==============================] - 260s 167ms/step - loss: 13.9101 - shap_loss: 13.9101 - eff_loss: 0.0000e+00 - val_loss: 15.7134 - val_shap_loss: 15.7134 - val_eff_loss: 0.0000e+00
# Epoch 64/100
# 1563/1563 [==============================] - ETA: 0s - loss: 13.8835 - shap_loss: 13.8835 - eff_loss: 0.0000e+00
# Epoch 00064: val_shap_loss did not improve from 15.50072
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
# 1563/1563 [==============================] - 260s 167ms/step - loss: 13.8835 - shap_loss: 13.8835 - eff_loss: 0.0000e+00 - val_loss: 15.6234 - val_shap_loss: 15.6234 - val_eff_loss: 0.0000e+00
# Epoch 65/100
# 1563/1563 [==============================] - ETA: 0s - loss: 13.9142 - shap_loss: 13.9142 - eff_loss: 0.0000e+00
# Epoch 00065: val_shap_loss did not improve from 15.50072
# 1563/1563 [==============================] - 260s 167ms/step - loss: 13.9142 - shap_loss: 13.9142 - eff_loss: 0.0000e+00 - val_loss: 15.9811 - val_shap_loss: 15.9811 - val_eff_loss: 0.0000e+00
# Epoch 66/100
# 1563/1563 [==============================] - ETA: 0s - loss: 13.8710 - shap_loss: 13.8710 - eff_loss: 0.0000e+00
# Epoch 00066: val_shap_loss did not improve from 15.50072
# 1563/1563 [==============================] - 260s 167ms/step - loss: 13.8710 - shap_loss: 13.8710 - eff_loss: 0.0000e+00 - val_loss: 15.7477 - val_shap_loss: 15.7477 - val_eff_loss: 0.0000e+00
# Epoch 67/100
# 1563/1563 [==============================] - ETA: 0s - loss: 13.9365 - shap_loss: 13.9365 - eff_loss: 0.0000e+00
# Epoch 00067: val_shap_loss did not improve from 15.50072
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
# 1563/1563 [==============================] - 260s 167ms/step - loss: 13.9365 - shap_loss: 13.9365 - eff_loss: 0.0000e+00 - val_loss: 16.1873 - val_shap_loss: 16.1873 - val_eff_loss: 0.0000e+00
# Epoch 68/100
# 1563/1563 [==============================] - ETA: 0s - loss: 13.8864 - shap_loss: 13.8864 - eff_loss: 0.0000e+00
# Epoch 00068: val_shap_loss did not improve from 15.50072
# 1563/1563 [==============================] - 260s 166ms/step - loss: 13.8864 - shap_loss: 13.8864 - eff_loss: 0.0000e+00 - val_loss: 15.8767 - val_shap_loss: 15.8767 - val_eff_loss: 0.0000e+00
# Epoch 69/100
# 1563/1563 [==============================] - ETA: 0s - loss: 13.7502 - shap_loss: 13.7502 - eff_loss: 0.0000e+00
# Epoch 00069: val_shap_loss did not improve from 15.50072
# 1563/1563 [==============================] - 260s 167ms/step - loss: 13.7502 - shap_loss: 13.7502 - eff_loss: 0.0000e+00 - val_loss: 15.7660 - val_shap_loss: 15.7660 - val_eff_loss: 0.0000e+00
# Epoch 70/100
# 1563/1563 [==============================] - ETA: 0s - loss: 13.8139 - shap_loss: 13.8139 - eff_loss: 0.0000e+00
# Epoch 00070: val_shap_loss did not improve from 15.50072
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
# 1563/1563 [==============================] - 260s 167ms/step - loss: 13.8139 - shap_loss: 13.8139 - eff_loss: 0.0000e+00 - val_loss: 15.7739 - val_shap_loss: 15.7739 - val_eff_loss: 0.0000e+00
# Epoch 71/100
# 1563/1563 [==============================] - ETA: 0s - loss: 13.8687 - shap_loss: 13.8687 - eff_loss: 0.0000e+00
# Epoch 00071: val_shap_loss did not improve from 15.50072
# 1563/1563 [==============================] - 260s 167ms/step - loss: 13.8687 - shap_loss: 13.8687 - eff_loss: 0.0000e+00 - val_loss: 15.9357 - val_shap_loss: 15.9357 - val_eff_loss: 0.0000e+00
# Epoch 72/100
# 1563/1563 [==============================] - ETA: 0s - loss: 13.8004 - shap_loss: 13.8004 - eff_loss: 0.0000e+00
# Epoch 00072: val_shap_loss did not improve from 15.50072
# 1563/1563 [==============================] - 260s 167ms/step - loss: 13.8004 - shap_loss: 13.8004 - eff_loss: 0.0000e+00 - val_loss: 15.8458 - val_shap_loss: 15.8458 - val_eff_loss: 0.0000e+00
# Epoch 73/100
# 1563/1563 [==============================] - ETA: 0s - loss: 13.8727 - shap_loss: 13.8727 - eff_loss: 0.0000e+00
# Epoch 00073: val_shap_loss did not improve from 15.50072
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
# 1563/1563 [==============================] - 260s 167ms/step - loss: 13.8727 - shap_loss: 13.8727 - eff_loss: 0.0000e+00 - val_loss: 15.9151 - val_shap_loss: 15.9151 - val_eff_loss: 0.0000e+00
# Epoch 74/100
# 1563/1563 [==============================] - ETA: 0s - loss: 13.8125 - shap_loss: 13.8125 - eff_loss: 0.0000e+00
# Epoch 00074: val_shap_loss did not improve from 15.50072
# 1563/1563 [==============================] - 261s 167ms/step - loss: 13.8125 - shap_loss: 13.8125 - eff_loss: 0.0000e+00 - val_loss: 15.8792 - val_shap_loss: 15.8792 - val_eff_loss: 0.0000e+00
# Epoch 75/100
# 1563/1563 [==============================] - ETA: 0s - loss: 13.8032 - shap_loss: 13.8032 - eff_loss: 0.0000e+00
# Epoch 00075: val_shap_loss did not improve from 15.50072
# 1563/1563 [==============================] - 261s 167ms/step - loss: 13.8032 - shap_loss: 13.8032 - eff_loss: 0.0000e+00 - val_loss: 16.0887 - val_shap_loss: 16.0887 - val_eff_loss: 0.0000e+00
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 224, 224, 3)]     0
# _________________________________________________________________
# functional_3 (Functional)    (None, 14, 14, 256)       4955520
# _________________________________________________________________
# conv2d (Conv2D)              (None, 14, 14, 10)        2570
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 196, 10)           0
# _________________________________________________________________
# permute (Permute)            (None, 10, 196)           0
# _________________________________________________________________
# phi (Layer)                  (None, 10, 196)           0
# =================================================================
# Total params: 4,958,090
# Trainable params: 4,939,274
# Non-trainable params: 18,816
# _________________________________________________________________

# %% [markdown]
# # Explain w/ FastSHAP

# %% [markdown]
# ### Load Images

# %%
images_dir = os.path.join(os.getcwd(), 'images')
images = np.load(os.path.join(images_dir, 'processed_images.npy'), allow_pickle=True)

# %% [markdown]
# ### Explain

# %%
t = time.time()
shap_values = fastshap.explainer.predict(images)
explaining_time = time.time() - t
shap_values = [shap_values[:,:,:,i] for i in range(10)]

# %% [markdown]
# ### Save

# %%
# save_dir = 'fastshap'
# model_dir = os.path.join(os.getcwd(), save_dir, 'results')
if not os.path.isdir(model_dir):
    os.makedirs(model_dir)

with open(os.path.join(model_dir, 'explaining_time.pkl'), 'wb') as f:
    pickle.dump(explaining_time, f)
    
with open(os.path.join(model_dir, 'shap_values.pkl'), 'wb') as f:
    pickle.dump(shap_values, f)
