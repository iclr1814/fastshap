# %%
import sys
sys.path.insert(0, '../../../fastshap_tf/')
from fastshap import ImageFastSHAP
from utils import ShapleySampler, ResizeMask
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd

# %%
import pickle
import numpy as np
import shap
from tqdm.notebook import tqdm
import time

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

from datetime import datetime
import os

# %%
from tensorflow.keras.layers import (Input, Layer, Dense, Lambda, Reshape, Multiply)
from tensorflow.keras.models import Model, Sequential

# %%
#Select GPU
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
# IMPORTANT: SET RANDOM SEEDS FOR REPRODUCIBILITY
os.environ['PYTHONHASHSEED'] = str(420)
import random
random.seed(420)
np.random.seed(420)
tf.random.set_seed(420)

# %% [markdown]
# ## Load Data

# %%
(ds_train, ds_val, ds_test), ds_info = tfds.load(
    'imagenette/full-size-v2',
    split=['train', 'validation[:50%]', 'validation[-50%:]'],
    as_supervised=False,
    with_info=True
)

# %% [markdown]
# ### Batch Data

# %%
def batch_data(dataset, fn, batch_size=32):
    dataset = dataset.map(fn)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    
    return dataset

# %% [markdown]
# ### Reformat Data

# %%
BATCH_SIZE = 32

def reformat(input_dict):
    
    i = input_dict['image']
    i = tf.cast(i, tf.float32)
    i = tf.image.resize_with_crop_or_pad(i, 224, 224)
    i = tf.keras.applications.resnet50.preprocess_input(i)
    
    l = tf.one_hot(input_dict['label'], depth = 10)
    
    return (i, l)

ds_train = batch_data(ds_train, reformat, BATCH_SIZE)
ds_val = batch_data(ds_val, reformat, BATCH_SIZE)
ds_test = batch_data(ds_test, reformat, BATCH_SIZE)

# %% [markdown]
# ## Load Surrogate Imputer

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

input_shape = (224,224,3)
P = 14*14
value_model = ResNet50(
    include_top=False, weights='imagenet', 
    input_shape=input_shape, pooling='avg'
) 
D = 10

model_input = Input(shape=input_shape, dtype='float64', name='input')
S = ShapleySampler(P, paired_sampling=False, num_samples=1)(model_input)
S = Lambda(lambda x: tf.cast(x, tf.float32))(S)
S = Reshape((P,))(S)
S = ResizeMask(in_shape=input_shape, mask_size=P)(S)
xs = Multiply()([model_input, S])

net = value_model(xs)
out = Dense(D, activation='softmax')(net)

surrogate = Model(model_input, out)

# Get Checkpointed Model
weights_path = 'surrogate/20210511_21_47_45/value_weights.h5'
surrogate.load_weights(weights_path)

# Remove Masking Layer
# Remove Masking Layer
surrogate = Sequential(   
    [l for l in surrogate.layers[-2:]]
)
surrogate.trainable = False
# Out:
# WARNING:tensorflow:Layer shapley_sampler is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# WARNING:tensorflow:Layer shapley_sampler is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# WARNING:tensorflow:Layer multiply is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# WARNING:tensorflow:Layer multiply is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.

# %% [markdown]
# # Train FastSHAP

# %% [markdown]
# ### Save Dir

# %%
date = datetime.now().strftime("%Y%m%d_%H_%M_%S")
save_dir = 'fastshap'
model_dir = os.path.join(os.getcwd(), save_dir, date)
if not os.path.isdir(model_dir):
    os.makedirs(model_dir)

# %% [markdown]
# ### Initialize

# %%
from importlib import reload
import fastshap
import utils
reload(fastshap)
reload(utils)
from fastshap import ImageFastSHAP

# %%
fastshap = ImageFastSHAP(imputer = surrogate ,
                         normalization=None,
                         model_dir = model_dir, 
                         link='logit')

# %% [markdown]
# ### Train

# %%
t = time.time()
fastshap.train(train_data = ds_train, 
              val_data = ds_val, 
              max_epochs = 100, 
              batch_size = 32, 
              num_samples = 1,
              lr = 1e-3,
              paired_sampling = True, 
              eff_lambda = 0.0,
              verbose = 1,
              lookback = 20)
training_time = time.time() - t

with open(os.path.join(model_dir, 'training_time.pkl'), 'wb') as f:
    pickle.dump(training_time, f)
# Out:
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda_1), but
# are not present in its tracked objects:
#   <tf.Variable 'conv1_conv/kernel:0' shape=(7, 7, 3, 64) dtype=float32>
#   <tf.Variable 'conv1_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv1_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv1_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_0_conv/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
#   <tf.Variable 'conv2_block1_0_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block1_0_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block1_0_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block1_1_conv/kernel:0' shape=(1, 1, 64, 64) dtype=float32>
#   <tf.Variable 'conv2_block1_1_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_1_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_1_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_2_conv/kernel:0' shape=(3, 3, 64, 64) dtype=float32>
#   <tf.Variable 'conv2_block1_2_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_2_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_2_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_3_conv/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
#   <tf.Variable 'conv2_block1_3_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block1_3_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block1_3_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block2_1_conv/kernel:0' shape=(1, 1, 256, 64) dtype=float32>
#   <tf.Variable 'conv2_block2_1_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_1_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_1_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_2_conv/kernel:0' shape=(3, 3, 64, 64) dtype=float32>
#   <tf.Variable 'conv2_block2_2_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_2_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_2_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_3_conv/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
#   <tf.Variable 'conv2_block2_3_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block2_3_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block2_3_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block3_1_conv/kernel:0' shape=(1, 1, 256, 64) dtype=float32>
#   <tf.Variable 'conv2_block3_1_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_1_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_1_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_2_conv/kernel:0' shape=(3, 3, 64, 64) dtype=float32>
#   <tf.Variable 'conv2_block3_2_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_2_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_2_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_3_conv/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
#   <tf.Variable 'conv2_block3_3_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block3_3_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block3_3_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv3_block1_0_conv/kernel:0' shape=(1, 1, 256, 512) dtype=float32>
#   <tf.Variable 'conv3_block1_0_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block1_0_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block1_0_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block1_1_conv/kernel:0' shape=(1, 1, 256, 128) dtype=float32>
#   <tf.Variable 'conv3_block1_1_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_1_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_1_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_2_conv/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
#   <tf.Variable 'conv3_block1_2_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_2_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_2_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_3_conv/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
#   <tf.Variable 'conv3_block1_3_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block1_3_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block1_3_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block2_1_conv/kernel:0' shape=(1, 1, 512, 128) dtype=float32>
#   <tf.Variable 'conv3_block2_1_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_1_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_1_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_2_conv/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
#   <tf.Variable 'conv3_block2_2_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_2_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_2_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_3_conv/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
#   <tf.Variable 'conv3_block2_3_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block2_3_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block2_3_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block3_1_conv/kernel:0' shape=(1, 1, 512, 128) dtype=float32>
#   <tf.Variable 'conv3_block3_1_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_1_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_1_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_2_conv/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
#   <tf.Variable 'conv3_block3_2_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_2_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_2_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_3_conv/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
#   <tf.Variable 'conv3_block3_3_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block3_3_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block3_3_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block4_1_conv/kernel:0' shape=(1, 1, 512, 128) dtype=float32>
#   <tf.Variable 'conv3_block4_1_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_1_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_1_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_2_conv/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
#   <tf.Variable 'conv3_block4_2_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_2_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_2_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_3_conv/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
#   <tf.Variable 'conv3_block4_3_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block4_3_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block4_3_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv4_block1_0_conv/kernel:0' shape=(1, 1, 512, 1024) dtype=float32>
#   <tf.Variable 'conv4_block1_0_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block1_0_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block1_0_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block1_1_conv/kernel:0' shape=(1, 1, 512, 256) dtype=float32>
#   <tf.Variable 'conv4_block1_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block1_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block1_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block1_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block1_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block2_1_conv/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
#   <tf.Variable 'conv4_block2_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block2_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block2_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block2_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block2_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block3_1_conv/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
#   <tf.Variable 'conv4_block3_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block3_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block3_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block3_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block3_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block4_1_conv/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
#   <tf.Variable 'conv4_block4_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block4_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block4_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block4_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block4_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block5_1_conv/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
#   <tf.Variable 'conv4_block5_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block5_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block5_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block5_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block5_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block6_1_conv/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
#   <tf.Variable 'conv4_block6_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block6_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block6_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block6_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block6_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv5_block1_0_conv/kernel:0' shape=(1, 1, 1024, 2048) dtype=float32>
#   <tf.Variable 'conv5_block1_0_conv/bias:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block1_0_bn/gamma:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block1_0_bn/beta:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block1_1_conv/kernel:0' shape=(1, 1, 1024, 512) dtype=float32>
#   <tf.Variable 'conv5_block1_1_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_1_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_1_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_2_conv/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
#   <tf.Variable 'conv5_block1_2_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_2_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_2_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_3_conv/kernel:0' shape=(1, 1, 512, 2048) dtype=float32>
#   <tf.Variable 'conv5_block1_3_conv/bias:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block1_3_bn/gamma:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block1_3_bn/beta:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block2_1_conv/kernel:0' shape=(1, 1, 2048, 512) dtype=float32>
#   <tf.Variable 'conv5_block2_1_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_1_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_1_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_2_conv/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
#   <tf.Variable 'conv5_block2_2_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_2_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_2_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_3_conv/kernel:0' shape=(1, 1, 512, 2048) dtype=float32>
#   <tf.Variable 'conv5_block2_3_conv/bias:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block2_3_bn/gamma:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block2_3_bn/beta:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block3_1_conv/kernel:0' shape=(1, 1, 2048, 512) dtype=float32>
#   <tf.Variable 'conv5_block3_1_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_1_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_1_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_2_conv/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
#   <tf.Variable 'conv5_block3_2_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_2_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_2_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_3_conv/kernel:0' shape=(1, 1, 512, 2048) dtype=float32>
#   <tf.Variable 'conv5_block3_3_conv/bias:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block3_3_bn/gamma:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block3_3_bn/beta:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'dense/kernel:0' shape=(2048, 10) dtype=float32>
#   <tf.Variable 'dense/bias:0' shape=(10,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda_1), but
# are not present in its tracked objects:
#   <tf.Variable 'conv1_conv/kernel:0' shape=(7, 7, 3, 64) dtype=float32>
#   <tf.Variable 'conv1_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv1_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv1_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_0_conv/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
#   <tf.Variable 'conv2_block1_0_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block1_0_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block1_0_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block1_1_conv/kernel:0' shape=(1, 1, 64, 64) dtype=float32>
#   <tf.Variable 'conv2_block1_1_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_1_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_1_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_2_conv/kernel:0' shape=(3, 3, 64, 64) dtype=float32>
#   <tf.Variable 'conv2_block1_2_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_2_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_2_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block1_3_conv/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
#   <tf.Variable 'conv2_block1_3_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block1_3_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block1_3_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block2_1_conv/kernel:0' shape=(1, 1, 256, 64) dtype=float32>
#   <tf.Variable 'conv2_block2_1_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_1_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_1_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_2_conv/kernel:0' shape=(3, 3, 64, 64) dtype=float32>
#   <tf.Variable 'conv2_block2_2_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_2_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_2_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block2_3_conv/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
#   <tf.Variable 'conv2_block2_3_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block2_3_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block2_3_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block3_1_conv/kernel:0' shape=(1, 1, 256, 64) dtype=float32>
#   <tf.Variable 'conv2_block3_1_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_1_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_1_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_2_conv/kernel:0' shape=(3, 3, 64, 64) dtype=float32>
#   <tf.Variable 'conv2_block3_2_conv/bias:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_2_bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_2_bn/beta:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_block3_3_conv/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
#   <tf.Variable 'conv2_block3_3_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block3_3_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_block3_3_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv3_block1_0_conv/kernel:0' shape=(1, 1, 256, 512) dtype=float32>
#   <tf.Variable 'conv3_block1_0_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block1_0_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block1_0_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block1_1_conv/kernel:0' shape=(1, 1, 256, 128) dtype=float32>
#   <tf.Variable 'conv3_block1_1_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_1_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_1_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_2_conv/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
#   <tf.Variable 'conv3_block1_2_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_2_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_2_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block1_3_conv/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
#   <tf.Variable 'conv3_block1_3_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block1_3_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block1_3_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block2_1_conv/kernel:0' shape=(1, 1, 512, 128) dtype=float32>
#   <tf.Variable 'conv3_block2_1_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_1_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_1_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_2_conv/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
#   <tf.Variable 'conv3_block2_2_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_2_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_2_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block2_3_conv/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
#   <tf.Variable 'conv3_block2_3_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block2_3_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block2_3_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block3_1_conv/kernel:0' shape=(1, 1, 512, 128) dtype=float32>
#   <tf.Variable 'conv3_block3_1_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_1_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_1_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_2_conv/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
#   <tf.Variable 'conv3_block3_2_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_2_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_2_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block3_3_conv/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
#   <tf.Variable 'conv3_block3_3_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block3_3_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block3_3_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block4_1_conv/kernel:0' shape=(1, 1, 512, 128) dtype=float32>
#   <tf.Variable 'conv3_block4_1_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_1_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_1_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_2_conv/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
#   <tf.Variable 'conv3_block4_2_conv/bias:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_2_bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_2_bn/beta:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_block4_3_conv/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
#   <tf.Variable 'conv3_block4_3_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block4_3_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_block4_3_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv4_block1_0_conv/kernel:0' shape=(1, 1, 512, 1024) dtype=float32>
#   <tf.Variable 'conv4_block1_0_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block1_0_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block1_0_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block1_1_conv/kernel:0' shape=(1, 1, 512, 256) dtype=float32>
#   <tf.Variable 'conv4_block1_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block1_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block1_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block1_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block1_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block1_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block2_1_conv/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
#   <tf.Variable 'conv4_block2_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block2_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block2_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block2_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block2_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block2_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block3_1_conv/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
#   <tf.Variable 'conv4_block3_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block3_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block3_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block3_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block3_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block3_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block4_1_conv/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
#   <tf.Variable 'conv4_block4_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block4_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block4_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block4_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block4_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block4_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block5_1_conv/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
#   <tf.Variable 'conv4_block5_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block5_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block5_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block5_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block5_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block5_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block6_1_conv/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
#   <tf.Variable 'conv4_block6_1_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_1_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_1_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_2_conv/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
#   <tf.Variable 'conv4_block6_2_conv/bias:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_2_bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_2_bn/beta:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_block6_3_conv/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
#   <tf.Variable 'conv4_block6_3_conv/bias:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block6_3_bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_block6_3_bn/beta:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv5_block1_0_conv/kernel:0' shape=(1, 1, 1024, 2048) dtype=float32>
#   <tf.Variable 'conv5_block1_0_conv/bias:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block1_0_bn/gamma:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block1_0_bn/beta:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block1_1_conv/kernel:0' shape=(1, 1, 1024, 512) dtype=float32>
#   <tf.Variable 'conv5_block1_1_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_1_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_1_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_2_conv/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
#   <tf.Variable 'conv5_block1_2_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_2_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_2_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block1_3_conv/kernel:0' shape=(1, 1, 512, 2048) dtype=float32>
#   <tf.Variable 'conv5_block1_3_conv/bias:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block1_3_bn/gamma:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block1_3_bn/beta:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block2_1_conv/kernel:0' shape=(1, 1, 2048, 512) dtype=float32>
#   <tf.Variable 'conv5_block2_1_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_1_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_1_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_2_conv/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
#   <tf.Variable 'conv5_block2_2_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_2_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_2_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block2_3_conv/kernel:0' shape=(1, 1, 512, 2048) dtype=float32>
#   <tf.Variable 'conv5_block2_3_conv/bias:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block2_3_bn/gamma:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block2_3_bn/beta:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block3_1_conv/kernel:0' shape=(1, 1, 2048, 512) dtype=float32>
#   <tf.Variable 'conv5_block3_1_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_1_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_1_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_2_conv/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
#   <tf.Variable 'conv5_block3_2_conv/bias:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_2_bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_2_bn/beta:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv5_block3_3_conv/kernel:0' shape=(1, 1, 512, 2048) dtype=float32>
#   <tf.Variable 'conv5_block3_3_conv/bias:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block3_3_bn/gamma:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'conv5_block3_3_bn/beta:0' shape=(2048,) dtype=float32>
#   <tf.Variable 'dense/kernel:0' shape=(2048, 10) dtype=float32>
#   <tf.Variable 'dense/bias:0' shape=(10,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# Epoch 1/100
# 296/296 [==============================] - ETA: 0s - loss: 178.5032 - shap_loss: 178.5032 - eff_loss: 0.0000e+00
# Epoch 00001: val_shap_loss improved from inf to 24.42870, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/imagenette/fastshap/20210519_16_09_16/explainer_weights.h5
# 296/296 [==============================] - 205s 692ms/step - loss: 178.5032 - shap_loss: 178.5032 - eff_loss: 0.0000e+00 - val_loss: 24.4287 - val_shap_loss: 24.4287 - val_eff_loss: 0.0000e+00
# Epoch 2/100
# 296/296 [==============================] - ETA: 0s - loss: 28.1514 - shap_loss: 28.1514 - eff_loss: 0.0000e+00
# Epoch 00002: val_shap_loss improved from 24.42870 to 22.15116, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/imagenette/fastshap/20210519_16_09_16/explainer_weights.h5
# 296/296 [==============================] - 56s 188ms/step - loss: 28.1514 - shap_loss: 28.1514 - eff_loss: 0.0000e+00 - val_loss: 22.1512 - val_shap_loss: 22.1512 - val_eff_loss: 0.0000e+00
# Epoch 3/100
# 296/296 [==============================] - ETA: 0s - loss: 24.4203 - shap_loss: 24.4203 - eff_loss: 0.0000e+00
# Epoch 00003: val_shap_loss did not improve from 22.15116
# 296/296 [==============================] - 54s 184ms/step - loss: 24.4203 - shap_loss: 24.4203 - eff_loss: 0.0000e+00 - val_loss: 24.1671 - val_shap_loss: 24.1671 - val_eff_loss: 0.0000e+00
# Epoch 4/100
# 296/296 [==============================] - ETA: 0s - loss: 21.7112 - shap_loss: 21.7112 - eff_loss: 0.0000e+00
# Epoch 00004: val_shap_loss improved from 22.15116 to 17.93956, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/imagenette/fastshap/20210519_16_09_16/explainer_weights.h5
# 296/296 [==============================] - 55s 186ms/step - loss: 21.7112 - shap_loss: 21.7112 - eff_loss: 0.0000e+00 - val_loss: 17.9396 - val_shap_loss: 17.9396 - val_eff_loss: 0.0000e+00
# Epoch 5/100
# 296/296 [==============================] - ETA: 0s - loss: 20.6256 - shap_loss: 20.6256 - eff_loss: 0.0000e+00
# Epoch 00005: val_shap_loss did not improve from 17.93956
# 296/296 [==============================] - 55s 185ms/step - loss: 20.6256 - shap_loss: 20.6256 - eff_loss: 0.0000e+00 - val_loss: 18.2465 - val_shap_loss: 18.2465 - val_eff_loss: 0.0000e+00
# Epoch 6/100
# 296/296 [==============================] - ETA: 0s - loss: 19.6151 - shap_loss: 19.6151 - eff_loss: 0.0000e+00
# Epoch 00006: val_shap_loss improved from 17.93956 to 17.54804, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/imagenette/fastshap/20210519_16_09_16/explainer_weights.h5
# 296/296 [==============================] - 55s 186ms/step - loss: 19.6151 - shap_loss: 19.6151 - eff_loss: 0.0000e+00 - val_loss: 17.5480 - val_shap_loss: 17.5480 - val_eff_loss: 0.0000e+00
# Epoch 7/100
# 296/296 [==============================] - ETA: 0s - loss: 18.9051 - shap_loss: 18.9051 - eff_loss: 0.0000e+00
# Epoch 00007: val_shap_loss improved from 17.54804 to 17.15061, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/imagenette/fastshap/20210519_16_09_16/explainer_weights.h5
# 296/296 [==============================] - 55s 186ms/step - loss: 18.9051 - shap_loss: 18.9051 - eff_loss: 0.0000e+00 - val_loss: 17.1506 - val_shap_loss: 17.1506 - val_eff_loss: 0.0000e+00
# Epoch 8/100
# 296/296 [==============================] - ETA: 0s - loss: 18.4681 - shap_loss: 18.4681 - eff_loss: 0.0000e+00
# Epoch 00008: val_shap_loss did not improve from 17.15061
# 296/296 [==============================] - 55s 186ms/step - loss: 18.4681 - shap_loss: 18.4681 - eff_loss: 0.0000e+00 - val_loss: 18.1864 - val_shap_loss: 18.1864 - val_eff_loss: 0.0000e+00
# Epoch 9/100
# 296/296 [==============================] - ETA: 0s - loss: 17.9027 - shap_loss: 17.9027 - eff_loss: 0.0000e+00
# Epoch 00009: val_shap_loss did not improve from 17.15061
# 296/296 [==============================] - 55s 185ms/step - loss: 17.9027 - shap_loss: 17.9027 - eff_loss: 0.0000e+00 - val_loss: 18.7784 - val_shap_loss: 18.7784 - val_eff_loss: 0.0000e+00
# Epoch 10/100
# 296/296 [==============================] - ETA: 0s - loss: 17.7509 - shap_loss: 17.7509 - eff_loss: 0.0000e+00
# Epoch 00010: val_shap_loss did not improve from 17.15061
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 296/296 [==============================] - 55s 185ms/step - loss: 17.7509 - shap_loss: 17.7509 - eff_loss: 0.0000e+00 - val_loss: 21.8641 - val_shap_loss: 21.8641 - val_eff_loss: 0.0000e+00
# Epoch 11/100
# 296/296 [==============================] - ETA: 0s - loss: 16.7620 - shap_loss: 16.7620 - eff_loss: 0.0000e+00
# Epoch 00011: val_shap_loss did not improve from 17.15061
# 296/296 [==============================] - 55s 185ms/step - loss: 16.7620 - shap_loss: 16.7620 - eff_loss: 0.0000e+00 - val_loss: 19.2513 - val_shap_loss: 19.2513 - val_eff_loss: 0.0000e+00
# Epoch 12/100
# 296/296 [==============================] - ETA: 0s - loss: 16.5443 - shap_loss: 16.5443 - eff_loss: 0.0000e+00
# Epoch 00012: val_shap_loss did not improve from 17.15061
# 296/296 [==============================] - 55s 187ms/step - loss: 16.5443 - shap_loss: 16.5443 - eff_loss: 0.0000e+00 - val_loss: 18.6540 - val_shap_loss: 18.6540 - val_eff_loss: 0.0000e+00
# Epoch 13/100
# 296/296 [==============================] - ETA: 0s - loss: 16.6100 - shap_loss: 16.6100 - eff_loss: 0.0000e+00
# Epoch 00013: val_shap_loss did not improve from 17.15061
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 296/296 [==============================] - 55s 185ms/step - loss: 16.6100 - shap_loss: 16.6100 - eff_loss: 0.0000e+00 - val_loss: 19.6256 - val_shap_loss: 19.6256 - val_eff_loss: 0.0000e+00
# Epoch 14/100
# 296/296 [==============================] - ETA: 0s - loss: 16.1364 - shap_loss: 16.1364 - eff_loss: 0.0000e+00
# Epoch 00014: val_shap_loss did not improve from 17.15061
# 296/296 [==============================] - 55s 184ms/step - loss: 16.1364 - shap_loss: 16.1364 - eff_loss: 0.0000e+00 - val_loss: 17.8072 - val_shap_loss: 17.8072 - val_eff_loss: 0.0000e+00
# Epoch 15/100
# 296/296 [==============================] - ETA: 0s - loss: 15.5763 - shap_loss: 15.5763 - eff_loss: 0.0000e+00
# Epoch 00015: val_shap_loss did not improve from 17.15061
# 296/296 [==============================] - 55s 184ms/step - loss: 15.5763 - shap_loss: 15.5763 - eff_loss: 0.0000e+00 - val_loss: 18.3041 - val_shap_loss: 18.3041 - val_eff_loss: 0.0000e+00
# Epoch 16/100
# 296/296 [==============================] - ETA: 0s - loss: 15.3238 - shap_loss: 15.3238 - eff_loss: 0.0000e+00
# Epoch 00016: val_shap_loss did not improve from 17.15061
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# 296/296 [==============================] - 54s 184ms/step - loss: 15.3238 - shap_loss: 15.3238 - eff_loss: 0.0000e+00 - val_loss: 17.7644 - val_shap_loss: 17.7644 - val_eff_loss: 0.0000e+00
# Epoch 17/100
# 296/296 [==============================] - ETA: 0s - loss: 14.7009 - shap_loss: 14.7009 - eff_loss: 0.0000e+00
# Epoch 00017: val_shap_loss did not improve from 17.15061
# 296/296 [==============================] - 55s 187ms/step - loss: 14.7009 - shap_loss: 14.7009 - eff_loss: 0.0000e+00 - val_loss: 17.4060 - val_shap_loss: 17.4060 - val_eff_loss: 0.0000e+00
# Epoch 18/100
# 296/296 [==============================] - ETA: 0s - loss: 14.8588 - shap_loss: 14.8588 - eff_loss: 0.0000e+00
# Epoch 00018: val_shap_loss did not improve from 17.15061
# 296/296 [==============================] - 55s 185ms/step - loss: 14.8588 - shap_loss: 14.8588 - eff_loss: 0.0000e+00 - val_loss: 19.6045 - val_shap_loss: 19.6045 - val_eff_loss: 0.0000e+00
# Epoch 19/100
# 296/296 [==============================] - ETA: 0s - loss: 14.4315 - shap_loss: 14.4315 - eff_loss: 0.0000e+00
# Epoch 00019: val_shap_loss did not improve from 17.15061
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# 296/296 [==============================] - 55s 184ms/step - loss: 14.4315 - shap_loss: 14.4315 - eff_loss: 0.0000e+00 - val_loss: 22.7002 - val_shap_loss: 22.7002 - val_eff_loss: 0.0000e+00
# Epoch 20/100
# 296/296 [==============================] - ETA: 0s - loss: 14.1798 - shap_loss: 14.1798 - eff_loss: 0.0000e+00
# Epoch 00020: val_shap_loss did not improve from 17.15061
# 296/296 [==============================] - 55s 185ms/step - loss: 14.1798 - shap_loss: 14.1798 - eff_loss: 0.0000e+00 - val_loss: 19.1917 - val_shap_loss: 19.1917 - val_eff_loss: 0.0000e+00
# Epoch 21/100
# 296/296 [==============================] - ETA: 0s - loss: 13.9170 - shap_loss: 13.9170 - eff_loss: 0.0000e+00
# Epoch 00021: val_shap_loss did not improve from 17.15061
# 296/296 [==============================] - 55s 185ms/step - loss: 13.9170 - shap_loss: 13.9170 - eff_loss: 0.0000e+00 - val_loss: 19.0088 - val_shap_loss: 19.0088 - val_eff_loss: 0.0000e+00
# Epoch 22/100
# 296/296 [==============================] - ETA: 0s - loss: 13.7141 - shap_loss: 13.7141 - eff_loss: 0.0000e+00
# Epoch 00022: val_shap_loss did not improve from 17.15061
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# 296/296 [==============================] - 55s 185ms/step - loss: 13.7141 - shap_loss: 13.7141 - eff_loss: 0.0000e+00 - val_loss: 19.5440 - val_shap_loss: 19.5440 - val_eff_loss: 0.0000e+00
# Epoch 23/100
# 296/296 [==============================] - ETA: 0s - loss: 13.5254 - shap_loss: 13.5254 - eff_loss: 0.0000e+00
# Epoch 00023: val_shap_loss did not improve from 17.15061
# 296/296 [==============================] - 55s 186ms/step - loss: 13.5254 - shap_loss: 13.5254 - eff_loss: 0.0000e+00 - val_loss: 17.8702 - val_shap_loss: 17.8702 - val_eff_loss: 0.0000e+00
# Epoch 24/100
# 296/296 [==============================] - ETA: 0s - loss: 13.1936 - shap_loss: 13.1936 - eff_loss: 0.0000e+00
# Epoch 00024: val_shap_loss improved from 17.15061 to 16.74248, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/imagenette/fastshap/20210519_16_09_16/explainer_weights.h5
# 296/296 [==============================] - 55s 187ms/step - loss: 13.1936 - shap_loss: 13.1936 - eff_loss: 0.0000e+00 - val_loss: 16.7425 - val_shap_loss: 16.7425 - val_eff_loss: 0.0000e+00
# Epoch 25/100
# 296/296 [==============================] - ETA: 0s - loss: 13.1625 - shap_loss: 13.1625 - eff_loss: 0.0000e+00
# Epoch 00025: val_shap_loss improved from 16.74248 to 16.50909, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/imagenette/fastshap/20210519_16_09_16/explainer_weights.h5
# 296/296 [==============================] - 55s 186ms/step - loss: 13.1625 - shap_loss: 13.1625 - eff_loss: 0.0000e+00 - val_loss: 16.5091 - val_shap_loss: 16.5091 - val_eff_loss: 0.0000e+00
# Epoch 26/100
# 296/296 [==============================] - ETA: 0s - loss: 13.2077 - shap_loss: 13.2077 - eff_loss: 0.0000e+00
# Epoch 00026: val_shap_loss did not improve from 16.50909
# 296/296 [==============================] - 55s 185ms/step - loss: 13.2077 - shap_loss: 13.2077 - eff_loss: 0.0000e+00 - val_loss: 18.9313 - val_shap_loss: 18.9313 - val_eff_loss: 0.0000e+00
# Epoch 27/100
# 296/296 [==============================] - ETA: 0s - loss: 13.1841 - shap_loss: 13.1841 - eff_loss: 0.0000e+00
# Epoch 00027: val_shap_loss did not improve from 16.50909
# 296/296 [==============================] - 55s 185ms/step - loss: 13.1841 - shap_loss: 13.1841 - eff_loss: 0.0000e+00 - val_loss: 17.3046 - val_shap_loss: 17.3046 - val_eff_loss: 0.0000e+00
# Epoch 28/100
# 296/296 [==============================] - ETA: 0s - loss: 12.9625 - shap_loss: 12.9625 - eff_loss: 0.0000e+00
# Epoch 00028: val_shap_loss did not improve from 16.50909
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# 296/296 [==============================] - 55s 185ms/step - loss: 12.9625 - shap_loss: 12.9625 - eff_loss: 0.0000e+00 - val_loss: 18.3754 - val_shap_loss: 18.3754 - val_eff_loss: 0.0000e+00
# Epoch 29/100
# 296/296 [==============================] - ETA: 0s - loss: 13.1157 - shap_loss: 13.1157 - eff_loss: 0.0000e+00
# Epoch 00029: val_shap_loss did not improve from 16.50909
# 296/296 [==============================] - 55s 185ms/step - loss: 13.1157 - shap_loss: 13.1157 - eff_loss: 0.0000e+00 - val_loss: 16.7655 - val_shap_loss: 16.7655 - val_eff_loss: 0.0000e+00
# Epoch 30/100
# 296/296 [==============================] - ETA: 0s - loss: 12.9112 - shap_loss: 12.9112 - eff_loss: 0.0000e+00
# Epoch 00030: val_shap_loss did not improve from 16.50909
# 296/296 [==============================] - 55s 185ms/step - loss: 12.9112 - shap_loss: 12.9112 - eff_loss: 0.0000e+00 - val_loss: 18.5335 - val_shap_loss: 18.5335 - val_eff_loss: 0.0000e+00
# Epoch 31/100
# 296/296 [==============================] - ETA: 0s - loss: 12.6102 - shap_loss: 12.6102 - eff_loss: 0.0000e+00
# Epoch 00031: val_shap_loss did not improve from 16.50909
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# 296/296 [==============================] - 55s 185ms/step - loss: 12.6102 - shap_loss: 12.6102 - eff_loss: 0.0000e+00 - val_loss: 16.7788 - val_shap_loss: 16.7788 - val_eff_loss: 0.0000e+00
# Epoch 32/100
# 296/296 [==============================] - ETA: 0s - loss: 12.5538 - shap_loss: 12.5538 - eff_loss: 0.0000e+00
# Epoch 00032: val_shap_loss did not improve from 16.50909
# 296/296 [==============================] - 55s 185ms/step - loss: 12.5538 - shap_loss: 12.5538 - eff_loss: 0.0000e+00 - val_loss: 17.0364 - val_shap_loss: 17.0364 - val_eff_loss: 0.0000e+00
# Epoch 33/100
# 296/296 [==============================] - ETA: 0s - loss: 12.2876 - shap_loss: 12.2876 - eff_loss: 0.0000e+00
# Epoch 00033: val_shap_loss improved from 16.50909 to 15.93727, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/imagenette/fastshap/20210519_16_09_16/explainer_weights.h5
# 296/296 [==============================] - 55s 186ms/step - loss: 12.2876 - shap_loss: 12.2876 - eff_loss: 0.0000e+00 - val_loss: 15.9373 - val_shap_loss: 15.9373 - val_eff_loss: 0.0000e+00
# Epoch 34/100
# 296/296 [==============================] - ETA: 0s - loss: 12.3515 - shap_loss: 12.3515 - eff_loss: 0.0000e+00
# Epoch 00034: val_shap_loss did not improve from 15.93727
# 296/296 [==============================] - 55s 184ms/step - loss: 12.3515 - shap_loss: 12.3515 - eff_loss: 0.0000e+00 - val_loss: 16.9724 - val_shap_loss: 16.9724 - val_eff_loss: 0.0000e+00
# Epoch 35/100
# 296/296 [==============================] - ETA: 0s - loss: 12.0611 - shap_loss: 12.0611 - eff_loss: 0.0000e+00
# Epoch 00035: val_shap_loss did not improve from 15.93727
# 296/296 [==============================] - 55s 185ms/step - loss: 12.0611 - shap_loss: 12.0611 - eff_loss: 0.0000e+00 - val_loss: 16.7193 - val_shap_loss: 16.7193 - val_eff_loss: 0.0000e+00
# Epoch 36/100
# 296/296 [==============================] - ETA: 0s - loss: 12.0766 - shap_loss: 12.0766 - eff_loss: 0.0000e+00
# Epoch 00036: val_shap_loss did not improve from 15.93727
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
# 296/296 [==============================] - 55s 184ms/step - loss: 12.0766 - shap_loss: 12.0766 - eff_loss: 0.0000e+00 - val_loss: 16.0597 - val_shap_loss: 16.0597 - val_eff_loss: 0.0000e+00
# Epoch 37/100
# 296/296 [==============================] - ETA: 0s - loss: 12.1060 - shap_loss: 12.1060 - eff_loss: 0.0000e+00
# Epoch 00037: val_shap_loss improved from 15.93727 to 15.59433, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/imagenette/fastshap/20210519_16_09_16/explainer_weights.h5
# 296/296 [==============================] - 55s 186ms/step - loss: 12.1060 - shap_loss: 12.1060 - eff_loss: 0.0000e+00 - val_loss: 15.5943 - val_shap_loss: 15.5943 - val_eff_loss: 0.0000e+00
# Epoch 38/100
# ...
# Epoch 40/100
# 296/296 [==============================] - ETA: 0s - loss: 11.8306 - shap_loss: 11.8306 - eff_loss: 0.0000e+00
# Epoch 00040: val_shap_loss did not improve from 15.59433
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
# 296/296 [==============================] - 55s 185ms/step - loss: 11.8306 - shap_loss: 11.8306 - eff_loss: 0.0000e+00 - val_loss: 17.6307 - val_shap_loss: 17.6307 - val_eff_loss: 0.0000e+00
# Epoch 41/100
# 296/296 [==============================] - ETA: 0s - loss: 11.5453 - shap_loss: 11.5453 - eff_loss: 0.0000e+00
# Epoch 00041: val_shap_loss improved from 15.59433 to 15.07786, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/imagenette/fastshap/20210519_16_09_16/explainer_weights.h5
# 296/296 [==============================] - 55s 186ms/step - loss: 11.5453 - shap_loss: 11.5453 - eff_loss: 0.0000e+00 - val_loss: 15.0779 - val_shap_loss: 15.0779 - val_eff_loss: 0.0000e+00
# Epoch 42/100
# 296/296 [==============================] - ETA: 0s - loss: 11.4603 - shap_loss: 11.4603 - eff_loss: 0.0000e+00
# Epoch 00042: val_shap_loss improved from 15.07786 to 15.06184, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/imagenette/fastshap/20210519_16_09_16/explainer_weights.h5
# 296/296 [==============================] - 55s 186ms/step - loss: 11.4603 - shap_loss: 11.4603 - eff_loss: 0.0000e+00 - val_loss: 15.0618 - val_shap_loss: 15.0618 - val_eff_loss: 0.0000e+00
# Epoch 43/100
# 296/296 [==============================] - ETA: 0s - loss: 11.7912 - shap_loss: 11.7912 - eff_loss: 0.0000e+00
# Epoch 00043: val_shap_loss did not improve from 15.06184
# 296/296 [==============================] - 55s 185ms/step - loss: 11.7912 - shap_loss: 11.7912 - eff_loss: 0.0000e+00 - val_loss: 15.7144 - val_shap_loss: 15.7144 - val_eff_loss: 0.0000e+00
# Epoch 44/100
# 296/296 [==============================] - ETA: 0s - loss: 11.5041 - shap_loss: 11.5041 - eff_loss: 0.0000e+00
# Epoch 00044: val_shap_loss did not improve from 15.06184
# 296/296 [==============================] - 55s 185ms/step - loss: 11.5041 - shap_loss: 11.5041 - eff_loss: 0.0000e+00 - val_loss: 16.3483 - val_shap_loss: 16.3483 - val_eff_loss: 0.0000e+00
# Epoch 45/100
# 296/296 [==============================] - ETA: 0s - loss: 11.6384 - shap_loss: 11.6384 - eff_loss: 0.0000e+00
# Epoch 00045: val_shap_loss did not improve from 15.06184
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
# 296/296 [==============================] - 55s 185ms/step - loss: 11.6384 - shap_loss: 11.6384 - eff_loss: 0.0000e+00 - val_loss: 15.4702 - val_shap_loss: 15.4702 - val_eff_loss: 0.0000e+00
# Epoch 46/100
# 296/296 [==============================] - ETA: 0s - loss: 11.4924 - shap_loss: 11.4924 - eff_loss: 0.0000e+00
# Epoch 00046: val_shap_loss did not improve from 15.06184
# 296/296 [==============================] - 55s 187ms/step - loss: 11.4924 - shap_loss: 11.4924 - eff_loss: 0.0000e+00 - val_loss: 16.2515 - val_shap_loss: 16.2515 - val_eff_loss: 0.0000e+00
# Epoch 47/100
# 296/296 [==============================] - ETA: 0s - loss: 11.4414 - shap_loss: 11.4414 - eff_loss: 0.0000e+00
# Epoch 00047: val_shap_loss did not improve from 15.06184
# 296/296 [==============================] - 55s 185ms/step - loss: 11.4414 - shap_loss: 11.4414 - eff_loss: 0.0000e+00 - val_loss: 15.6731 - val_shap_loss: 15.6731 - val_eff_loss: 0.0000e+00
# Epoch 48/100
# 296/296 [==============================] - ETA: 0s - loss: 11.1872 - shap_loss: 11.1872 - eff_loss: 0.0000e+00
# Epoch 00048: val_shap_loss did not improve from 15.06184
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
# 296/296 [==============================] - 55s 185ms/step - loss: 11.1872 - shap_loss: 11.1872 - eff_loss: 0.0000e+00 - val_loss: 15.6601 - val_shap_loss: 15.6601 - val_eff_loss: 0.0000e+00
# Epoch 49/100
# 296/296 [==============================] - ETA: 0s - loss: 11.1587 - shap_loss: 11.1587 - eff_loss: 0.0000e+00
# Epoch 00049: val_shap_loss did not improve from 15.06184
# 296/296 [==============================] - 55s 184ms/step - loss: 11.1587 - shap_loss: 11.1587 - eff_loss: 0.0000e+00 - val_loss: 15.9444 - val_shap_loss: 15.9444 - val_eff_loss: 0.0000e+00
# Epoch 50/100
# 296/296 [==============================] - ETA: 0s - loss: 11.1767 - shap_loss: 11.1767 - eff_loss: 0.0000e+00
# Epoch 00050: val_shap_loss did not improve from 15.06184
# 296/296 [==============================] - 55s 185ms/step - loss: 11.1767 - shap_loss: 11.1767 - eff_loss: 0.0000e+00 - val_loss: 15.4037 - val_shap_loss: 15.4037 - val_eff_loss: 0.0000e+00
# Epoch 51/100
# 296/296 [==============================] - ETA: 0s - loss: 11.2256 - shap_loss: 11.2256 - eff_loss: 0.0000e+00
# Epoch 00051: val_shap_loss improved from 15.06184 to 15.05638, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/imagenette/fastshap/20210519_16_09_16/explainer_weights.h5
# 296/296 [==============================] - 55s 187ms/step - loss: 11.2256 - shap_loss: 11.2256 - eff_loss: 0.0000e+00 - val_loss: 15.0564 - val_shap_loss: 15.0564 - val_eff_loss: 0.0000e+00
# Epoch 52/100
# 296/296 [==============================] - ETA: 0s - loss: 11.2439 - shap_loss: 11.2439 - eff_loss: 0.0000e+00
# Epoch 00052: val_shap_loss did not improve from 15.05638
# 296/296 [==============================] - 55s 185ms/step - loss: 11.2439 - shap_loss: 11.2439 - eff_loss: 0.0000e+00 - val_loss: 15.6451 - val_shap_loss: 15.6451 - val_eff_loss: 0.0000e+00
# Epoch 53/100
# 296/296 [==============================] - ETA: 0s - loss: 11.0412 - shap_loss: 11.0412 - eff_loss: 0.0000e+00
# Epoch 00053: val_shap_loss did not improve from 15.05638
# 296/296 [==============================] - 54s 184ms/step - loss: 11.0412 - shap_loss: 11.0412 - eff_loss: 0.0000e+00 - val_loss: 15.9253 - val_shap_loss: 15.9253 - val_eff_loss: 0.0000e+00
# Epoch 54/100
# 296/296 [==============================] - ETA: 0s - loss: 10.9715 - shap_loss: 10.9715 - eff_loss: 0.0000e+00
# Epoch 00054: val_shap_loss did not improve from 15.05638
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
# 296/296 [==============================] - 55s 185ms/step - loss: 10.9715 - shap_loss: 10.9715 - eff_loss: 0.0000e+00 - val_loss: 15.5505 - val_shap_loss: 15.5505 - val_eff_loss: 0.0000e+00
# Epoch 55/100
# 296/296 [==============================] - ETA: 0s - loss: 11.0414 - shap_loss: 11.0414 - eff_loss: 0.0000e+00
# Epoch 00055: val_shap_loss improved from 15.05638 to 14.80786, saving model to /gpfs/data/paulab/nj594/fast_shap/experiments/images/imagenette/fastshap/20210519_16_09_16/explainer_weights.h5
# 296/296 [==============================] - 55s 186ms/step - loss: 11.0414 - shap_loss: 11.0414 - eff_loss: 0.0000e+00 - val_loss: 14.8079 - val_shap_loss: 14.8079 - val_eff_loss: 0.0000e+00
# Epoch 56/100
# 296/296 [==============================] - ETA: 0s - loss: 11.0656 - shap_loss: 11.0656 - eff_loss: 0.0000e+00
# Epoch 00056: val_shap_loss did not improve from 14.80786
# 296/296 [==============================] - 55s 185ms/step - loss: 11.0656 - shap_loss: 11.0656 - eff_loss: 0.0000e+00 - val_loss: 15.7514 - val_shap_loss: 15.7514 - val_eff_loss: 0.0000e+00
# Epoch 57/100
# 296/296 [==============================] - ETA: 0s - loss: 11.1301 - shap_loss: 11.1301 - eff_loss: 0.0000e+00
# Epoch 00057: val_shap_loss did not improve from 14.80786
# 296/296 [==============================] - 55s 184ms/step - loss: 11.1301 - shap_loss: 11.1301 - eff_loss: 0.0000e+00 - val_loss: 15.9239 - val_shap_loss: 15.9239 - val_eff_loss: 0.0000e+00
# Epoch 58/100
# 296/296 [==============================] - ETA: 0s - loss: 10.8627 - shap_loss: 10.8627 - eff_loss: 0.0000e+00
# Epoch 00058: val_shap_loss did not improve from 14.80786
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
# 296/296 [==============================] - 55s 184ms/step - loss: 10.8627 - shap_loss: 10.8627 - eff_loss: 0.0000e+00 - val_loss: 15.1409 - val_shap_loss: 15.1409 - val_eff_loss: 0.0000e+00
# Epoch 59/100
# 296/296 [==============================] - ETA: 0s - loss: 10.8594 - shap_loss: 10.8594 - eff_loss: 0.0000e+00
# Epoch 00059: val_shap_loss did not improve from 14.80786
# 296/296 [==============================] - 55s 185ms/step - loss: 10.8594 - shap_loss: 10.8594 - eff_loss: 0.0000e+00 - val_loss: 15.8143 - val_shap_loss: 15.8143 - val_eff_loss: 0.0000e+00
# Epoch 60/100
# 296/296 [==============================] - ETA: 0s - loss: 11.1593 - shap_loss: 11.1593 - eff_loss: 0.0000e+00
# Epoch 00060: val_shap_loss did not improve from 14.80786
# 296/296 [==============================] - 54s 184ms/step - loss: 11.1593 - shap_loss: 11.1593 - eff_loss: 0.0000e+00 - val_loss: 15.5042 - val_shap_loss: 15.5042 - val_eff_loss: 0.0000e+00
# Epoch 61/100
# 296/296 [==============================] - ETA: 0s - loss: 10.9547 - shap_loss: 10.9547 - eff_loss: 0.0000e+00
# Epoch 00061: val_shap_loss did not improve from 14.80786
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
# 296/296 [==============================] - 55s 185ms/step - loss: 10.9547 - shap_loss: 10.9547 - eff_loss: 0.0000e+00 - val_loss: 15.1069 - val_shap_loss: 15.1069 - val_eff_loss: 0.0000e+00
# Epoch 62/100
# 296/296 [==============================] - ETA: 0s - loss: 10.8713 - shap_loss: 10.8713 - eff_loss: 0.0000e+00
# Epoch 00062: val_shap_loss did not improve from 14.80786
# 296/296 [==============================] - 55s 185ms/step - loss: 10.8713 - shap_loss: 10.8713 - eff_loss: 0.0000e+00 - val_loss: 15.5539 - val_shap_loss: 15.5539 - val_eff_loss: 0.0000e+00
# Epoch 63/100
# 296/296 [==============================] - ETA: 0s - loss: 10.6768 - shap_loss: 10.6768 - eff_loss: 0.0000e+00
# Epoch 00063: val_shap_loss did not improve from 14.80786
# 296/296 [==============================] - 55s 185ms/step - loss: 10.6768 - shap_loss: 10.6768 - eff_loss: 0.0000e+00 - val_loss: 15.3889 - val_shap_loss: 15.3889 - val_eff_loss: 0.0000e+00
# Epoch 64/100
# 296/296 [==============================] - ETA: 0s - loss: 10.9787 - shap_loss: 10.9787 - eff_loss: 0.0000e+00
# Epoch 00064: val_shap_loss did not improve from 14.80786
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 3.518437442835421e-05.
# 296/296 [==============================] - 55s 185ms/step - loss: 10.9787 - shap_loss: 10.9787 - eff_loss: 0.0000e+00 - val_loss: 15.9617 - val_shap_loss: 15.9617 - val_eff_loss: 0.0000e+00
# Epoch 65/100
# 296/296 [==============================] - ETA: 0s - loss: 10.7038 - shap_loss: 10.7038 - eff_loss: 0.0000e+00
# Epoch 00065: val_shap_loss did not improve from 14.80786
# 296/296 [==============================] - 55s 185ms/step - loss: 10.7038 - shap_loss: 10.7038 - eff_loss: 0.0000e+00 - val_loss: 15.8301 - val_shap_loss: 15.8301 - val_eff_loss: 0.0000e+00
# Epoch 66/100
# 296/296 [==============================] - ETA: 0s - loss: 10.7957 - shap_loss: 10.7957 - eff_loss: 0.0000e+00
# Epoch 00066: val_shap_loss did not improve from 14.80786
# 296/296 [==============================] - 55s 185ms/step - loss: 10.7957 - shap_loss: 10.7957 - eff_loss: 0.0000e+00 - val_loss: 15.8239 - val_shap_loss: 15.8239 - val_eff_loss: 0.0000e+00
# Epoch 67/100
# 296/296 [==============================] - ETA: 0s - loss: 10.7174 - shap_loss: 10.7174 - eff_loss: 0.0000e+00
# Epoch 00067: val_shap_loss did not improve from 14.80786
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 2.8147498960606756e-05.
# 296/296 [==============================] - 55s 185ms/step - loss: 10.7174 - shap_loss: 10.7174 - eff_loss: 0.0000e+00 - val_loss: 16.2899 - val_shap_loss: 16.2899 - val_eff_loss: 0.0000e+00
# Epoch 68/100
# 296/296 [==============================] - ETA: 0s - loss: 10.6057 - shap_loss: 10.6057 - eff_loss: 0.0000e+00
# Epoch 00068: val_shap_loss did not improve from 14.80786
# 296/296 [==============================] - 55s 185ms/step - loss: 10.6057 - shap_loss: 10.6057 - eff_loss: 0.0000e+00 - val_loss: 15.9412 - val_shap_loss: 15.9412 - val_eff_loss: 0.0000e+00
# Epoch 69/100
# 296/296 [==============================] - ETA: 0s - loss: 10.7580 - shap_loss: 10.7580 - eff_loss: 0.0000e+00
# Epoch 00069: val_shap_loss did not improve from 14.80786
# 296/296 [==============================] - 55s 185ms/step - loss: 10.7580 - shap_loss: 10.7580 - eff_loss: 0.0000e+00 - val_loss: 15.5157 - val_shap_loss: 15.5157 - val_eff_loss: 0.0000e+00
# Epoch 70/100
# 296/296 [==============================] - ETA: 0s - loss: 10.5955 - shap_loss: 10.5955 - eff_loss: 0.0000e+00
# Epoch 00070: val_shap_loss did not improve from 14.80786
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 2.25179988774471e-05.
# 296/296 [==============================] - 55s 185ms/step - loss: 10.5955 - shap_loss: 10.5955 - eff_loss: 0.0000e+00 - val_loss: 16.0939 - val_shap_loss: 16.0939 - val_eff_loss: 0.0000e+00
# Epoch 71/100
# 296/296 [==============================] - ETA: 0s - loss: 10.8385 - shap_loss: 10.8385 - eff_loss: 0.0000e+00
# Epoch 00071: val_shap_loss did not improve from 14.80786
# 296/296 [==============================] - 55s 185ms/step - loss: 10.8385 - shap_loss: 10.8385 - eff_loss: 0.0000e+00 - val_loss: 16.1364 - val_shap_loss: 16.1364 - val_eff_loss: 0.0000e+00
# Epoch 72/100
# 296/296 [==============================] - ETA: 0s - loss: 10.6995 - shap_loss: 10.6995 - eff_loss: 0.0000e+00
# Epoch 00072: val_shap_loss did not improve from 14.80786
# 296/296 [==============================] - 55s 185ms/step - loss: 10.6995 - shap_loss: 10.6995 - eff_loss: 0.0000e+00 - val_loss: 15.6904 - val_shap_loss: 15.6904 - val_eff_loss: 0.0000e+00
# Epoch 73/100
# 296/296 [==============================] - ETA: 0s - loss: 10.5965 - shap_loss: 10.5965 - eff_loss: 0.0000e+00
# Epoch 00073: val_shap_loss did not improve from 14.80786
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 1.8014399392995985e-05.
# 296/296 [==============================] - 55s 185ms/step - loss: 10.5965 - shap_loss: 10.5965 - eff_loss: 0.0000e+00 - val_loss: 14.9767 - val_shap_loss: 14.9767 - val_eff_loss: 0.0000e+00
# Epoch 74/100
# 296/296 [==============================] - ETA: 0s - loss: 10.5739 - shap_loss: 10.5739 - eff_loss: 0.0000e+00
# Epoch 00074: val_shap_loss did not improve from 14.80786
# 296/296 [==============================] - 55s 184ms/step - loss: 10.5739 - shap_loss: 10.5739 - eff_loss: 0.0000e+00 - val_loss: 16.1187 - val_shap_loss: 16.1187 - val_eff_loss: 0.0000e+00
# Epoch 75/100
# 296/296 [==============================] - ETA: 0s - loss: 10.7194 - shap_loss: 10.7194 - eff_loss: 0.0000e+00
# Epoch 00075: val_shap_loss did not improve from 14.80786
# 296/296 [==============================] - 55s 187ms/step - loss: 10.7194 - shap_loss: 10.7194 - eff_loss: 0.0000e+00 - val_loss: 15.7010 - val_shap_loss: 15.7010 - val_eff_loss: 0.0000e+00
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 224, 224, 3)]     0
# _________________________________________________________________
# functional_3 (Functional)    (None, 14, 14, 256)       4955520
# _________________________________________________________________
# conv2d (Conv2D)              (None, 14, 14, 10)        2570
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 196, 10)           0
# _________________________________________________________________
# permute (Permute)            (None, 10, 196)           0
# _________________________________________________________________
# phi (Layer)                  (None, 10, 196)           0
# =================================================================
# Total params: 4,958,090
# Trainable params: 4,939,274
# Non-trainable params: 18,816
# _________________________________________________________________

# %% [markdown]
# # Explain w/ FastSHAP

# %% [markdown]
# ### Load Images

# %%
images_dir = os.path.join(os.getcwd(), 'images')
images = np.load(os.path.join(images_dir, 'processed_images.npy'), allow_pickle=True)

# %% [markdown]
# ### Explain

# %%
t = time.time()
shap_values = fastshap.explainer.predict(images)
explaining_time = time.time() - t
shap_values = [shap_values[:,:,:,i] for i in range(10)]

# %% [markdown]
# ### Save

# %%
# save_dir = 'fastshap'
# model_dir = os.path.join(os.getcwd(), save_dir, 'results')
if not os.path.isdir(model_dir):
    os.makedirs(model_dir)

with open(os.path.join(model_dir, 'explaining_time.pkl'), 'wb') as f:
    pickle.dump(explaining_time, f)
    
with open(os.path.join(model_dir, 'shap_values.pkl'), 'wb') as f:
    pickle.dump(shap_values, f)
